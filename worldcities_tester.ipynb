# %%
import csv
import pandas as pd
import numpy as np
import os
import random as rd

# %%
file = os.path.join('Resources','worldcities.csv')
data = pd.read_csv(file)

# %%
file = os.path.join('Resources','owm_citylist.txt')
owm_df = pd.read_csv(file, delimiter='\t')
owm_df.head()
# Out:
#         id               nm        lat        lon countryCode
# 0   819827         Razvilka  55.591667  37.740833          RU
# 1   524901           Moscow  55.752220  37.615555          RU
# 2  1271881  Firozpur Jhirka  27.799999  76.949997          IN
# 3  1283240        Kathmandu  27.716667  85.316666          NP
# 4   703448             Kiev  50.433334  30.516666          UA

# %%
# >>> df = pd.DataFrame(columns=['A'])
# >>> for i in range(5):
# ...     df = df.append({'A': i}, ignore_index=True)
# >>> df

def lat_random_select(number):
    range_num = int(number/7)
    id_list = []
    lat_list = []
    nm_list = []
    column_names = ['City', 'ID', 'Latitude']
    id_df = pd.DataFrame(columns=column_names)
    lat = np.arange(-60,100,20)
    for deg in range(1,len(lat)):
        range_ls = list(owm_df.loc[(owm_df['lat'] > lat[deg-1]) & (owm_df['lat'] <= lat[deg]),:]['id'])
        selections = rd.sample(range_ls, range_num)
        id_list = id_list + selections
    for city_id in id_list:
        selection = owm_df.loc[owm_df['id'] == city_id]
        name = list(selection['nm'])[0]
        lat = float(selection['lat'])
        lat_list.append(lat)
        nm_list.append(name)
    id_df['City'] = nm_list
    id_df['ID'] = id_list
    id_df['Latitude'] = lat_list
    return id_df

# %%
df = lat_random_select(100)

# %%
df
# Out:
#                    City       ID   Latitude
# 0                Gaiman  3855284 -43.289700
# 1          Los Antiguos  3846484 -46.549721
# 2              Hokitika  2206894 -42.716671
# 3             El Bolson  3858765 -41.966671
# 4          Puerto Montt  3874960 -41.469849
# 5               Dunedin  2191562 -45.874161
# 6               Chonchi  3894871 -42.612782
# 7             Arrowtown  6206253 -44.938370
# 8              Westport  2206900 -41.752621
# 9             Coihaique  3894426 -45.575241
# 10              Te Anau  2181625 -45.416672
# 11         Puerto Aisen  3874997 -45.400002
# 12           Upper Hutt  6244895 -41.138271
# 13             Trevelin  3833675 -43.085800
# 14            Goodlands   934488 -20.035000
# 15               Bovril  3435966 -31.343109
# 16            Westbrook  2144053 -27.616671
# 17             Katoomba  2161776 -33.719769
# 18            Narrabeen  2155745 -33.712769
# 19   Tamborine Mountain  6951440 -27.969540
# 20                Menai  2158130 -34.016670
# 21              Lambare  3437863 -25.346821
# 22           Lady Frere   985011 -31.703119
# 23              Armacao  3471490 -27.749630
# 24            Aguilares  3866496 -27.433800
# 25           Concepcion  3893894 -36.826988
# 26             Itaborai  3460950 -22.744440
# 27          Villa Berna  7304381 -31.903210
# 28               Shamva   881345 -17.311590
# 29     Sao Jose da Laje  3388454  -9.009720
# ..                  ...      ...        ...
# 68                Godda  1271113  24.833330
# 69                 Vedi   174725  39.914211
# 70             Viytivka   710949  48.426029
# 71              Swansea  2636432  51.620789
# 72           Egerszalok   721225  47.866669
# 73             Elmshorn  2930821  53.750000
# 74              Vilseck  2817207  49.610001
# 75            Ust-Koksa  1488167  50.269600
# 76               Sazava  3066385  49.871639
# 77                 Ejby  2622664  55.689232
# 78          East Moline  4890536  41.500870
# 79              Bamberg  2952984  49.879478
# 80  Montoir-de-Bretagne  2992206  47.330120
# 81               Vestby  3132058  59.602371
# 82               Khabez   550868  44.043400
# 83          Novyy Sulak   858712  43.211670
# 84         Kristinestad   650769  62.274288
# 85              Lakselv   779082  70.051331
# 86                 Auli  3162475  60.034500
# 87            Parikkala   642666  61.549999
# 88             Berezovo  1510214  63.938061
# 89             Hoyanger  3151574  61.220360
# 90                Voera   631254  63.136070
# 91        Seltjarnarnes  3414979  64.150002
# 92             Innbygda  3133819  61.314838
# 93              Kogalym  6695754  62.265369
# 94          Savitaipale   637312  61.200001
# 95        Zelenoborskiy   463838  66.845001
# 96            Rymattyla   638582  60.376579
# 97   Tsementnozavodskiy  1489126  67.616669
#
# [98 rows x 3 columns]

# %%
column_list = list(owm_df.columns)
column_names = ['City','ID','Latitude']
lat_list = []
nm_list = []
for city_id in ls:
    tester = owm_df.loc[owm_df['id'] == city_id]
    name = list(tester['nm'])[0]
    lat = float(tester['lat'])
    lat_list.append(lat)
    nm_list.append(name)


df_test = pd.DataFrame(columns=column_names)
df_test['City'] = nm_list
df_test['ID'] = ls
df_test['Latitude'] = lat_list
print(df_test.count())
df_test
# Out:
# City        98
# ID          98
# Latitude    98
# dtype: int64
#                             City       ID   Latitude
# 0                       Invermay  2205847 -41.391670
# 1                       Blenheim  6243926 -41.516029
# 2                         Trelew  3833883 -43.248951
# 3                         Osorno  3877949 -40.566669
# 4                          Levin  2206371 -40.633331
# 5               Palmerston North  2185018 -40.349998
# 6                        Woodend  2178982 -43.316669
# 7                        Margate  2158744 -43.033329
# 8                     Queenstown  2152272 -42.083328
# 9                      Greymouth  2206895 -42.466671
# 10                    Berriedale  2176066 -42.816669
# 11  Comandante Luis Piedra Buena  3860466 -49.985130
# 12                       Taroona  2147344 -42.950001
# 13                       Lincoln  2188371 -43.650002
# 14                   Twin Waters  6944968 -26.610001
# 15                 El Quebrachal  3857012 -25.283331
# 16                       Messina   976885 -22.351311
# 17                    Araraquara  3471766 -21.794439
# 18                       Penrith  2153471 -33.750000
# 19                         Penco  3876664 -36.733330
# 20         Santa Rita do Sapucai  3449847 -22.252220
# 21                      Dubreuil  1106788 -20.297501
# 22                Lenchwe Le Tau   933541 -24.383329
# 23                         Macia  1024701 -25.026939
# 24                Coronel Suarez  3860164 -37.454670
# 25                   Maryborough  2158562 -25.533331
# 26                   Forest Hill  7932633 -37.836559
# 27                         Greta  2164451 -32.700001
# 28                      Pariaman  1632334  -0.618980
# 29                      Oxapampa  3933874 -10.577500
# ..                           ...      ...        ...
# 68                     Arjonilla  2521593  37.974220
# 69                       Rampura  1258584  30.250000
# 70                   Zeytinburnu   737071  40.994411
# 71                     Pogorzela  3088548  51.822201
# 72                     Wanamassa  5106021  40.231781
# 73              Sainte-Radegonde  2980356  46.983330
# 74         Le Perray-en-Yvelines  3002967  48.694408
# 75                  Hackettstown  5098745  40.853989
# 76                        Vernet  2998879  43.433331
# 77                         Calvi  3029090  42.566040
# 78                      Cuglieri  3177719  40.187950
# 79                   Glattfelden  2660587  47.558708
# 80                   Obertrubach  2858765  49.700001
# 81                      Caravate  3180579  45.878880
# 82                        Evreux  3019265  49.024139
# 83                        Nantua  2990932  46.150002
# 84                         Dokka  3159143  60.840012
# 85                        Gjovik  3155573  60.795738
# 86                     Sortavala   490466  61.705318
# 87                    Luopioinen   647383  61.366669
# 88                          Nuuk  3421319  64.183472
# 89                          Luza   533143  60.630821
# 90                       College  5859699  64.856941
# 91                     Pyhajarvi   640440  67.071388
# 92                    Stroemsund  2671221  63.852058
# 93                       Agirish  1512101  61.924721
# 94                    Haukipudas   658629  65.176537
# 95                       Iisalmi   656820  63.559151
# 96                        Porvoo   660561  60.392330
# 97                     Priozersk   505230  61.039280
#
# [98 rows x 3 columns]

# %%
i_df
# Out:
# Empty DataFrame
# Columns: [id, nm, lat, lon, countryCode]
# Index: []

# %%
data.head()
# Out:
#   Country              City   Latitude  Longitude
# 0      ad  andorra la vella  42.500000   1.516667
# 1      ad           canillo  42.566667   1.600000
# 2      ad            encamp  42.533333   1.583333
# 3      ad        la massana  42.550000   1.516667
# 4      ad      les escaldes  42.500000   1.533333

# %%
data['Latitude'].max()
# Out:
# 78.216666700000005

# %%
data['Latitude'].min()
# Out:
# -54.799999999999997

# %%
data['Longitude'].max()
# Out:
# 179.316667

# %%
data['Longitude'].min()
# Out:
# -179.5

# %%
data.head()
# Out:
#   Country              City   Latitude  Longitude
# 0      ad  andorra la vella  42.500000   1.516667
# 1      ad           canillo  42.566667   1.600000
# 2      ad            encamp  42.533333   1.583333
# 3      ad        la massana  42.550000   1.516667
# 4      ad      les escaldes  42.500000   1.533333

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#   Country              City   Latitude  Longitude
# 0      ad  andorra la vella  42.500000   1.516667
# 1      ad           canillo  42.566667   1.600000
# 2      ad            encamp  42.533333   1.583333
# 3      ad        la massana  42.550000   1.516667
# 4      ad      les escaldes  42.500000   1.533333

# %%
df.loc[df['Latitude'] < -70,:]
# Out:
# Empty DataFrame
# Columns: [Country, City, Latitude, Longitude]
# Index: []

# %%
df.loc[(df['Latitude'] > -60) & (df['Latitude'] < -40),:]['City'].head()
# Out:
# 479         comodoro rivadavia
# 514              puerto madryn
# 517                     rawson
# 521               rio gallegos
# 526    san carlos de bariloche
# Name: City, dtype: object

# %%
lat = np.arange(-60,100,20)
lat
# Out:
# array([-60, -40, -20,   0,  20,  40,  60,  80])

# %%
for deg in range(1,len(lat)):
    print('{} to {}'.format(lat[deg-1],lat[deg]))
# Out:
# -60 to -40
# -40 to -20
# -20 to 0
# 0 to 20
# 20 to 40
# 40 to 60
# 60 to 80

# %%
low = list(df.loc[(df['Latitude'] > -60) & (df['Latitude'] <= -40),:]['City'])
low_random = rd.sample(low, 20)
low_random
# Out:
# ['purranque',
#  'hokitika',
#  'darfield',
#  'milton',
#  'bulls',
#  'rakaia',
#  'dunedin',
#  'puerto varas',
#  'castro',
#  'hobart',
#  'burnie',
#  'pleasant point',
#  'himatangi',
#  'hanmer springs',
#  'havelock',
#  'waipawa',
#  'porirua',
#  'kaitangata',
#  'te horo',
#  'launceston']

# %%
num = 80
city_ls = []
lat = np.arange(-60,100,20)
for deg in range(1,len(lat)):
    range_ls = list(df.loc[(df['Latitude'] > lat[deg-1]) & (df['Latitude'] <= lat[deg]),:]['City'])
    selections = rd.sample(range_ls, num)
    city_ls = city_ls + selections

len(city_ls)
# Out:
# 560

# %%
def ran_select(number):
    range_num = int(number/7)
    city_list = []
    lat = np.arange(-60,100,20)
    for deg in range(1,len(lat)):
        range_ls = list(df.loc[(df['Latitude'] > lat[deg-1]) & (df['Latitude'] <= lat[deg]),:]['City'])
        selections = rd.sample(range_ls, range_num)
        city_list = city_list + selections
    return city_list

# %%
ls = ran_select(50)

# %%
city_selection = []

for city in ls:
    df2 = data.set_index('City')
    latitude = df2.loc[city,'Latitude']
#     city_data = {
#         'City': city,
#         'Latitude': latitude
#     }
#     city_selection.append(city_data)
    print(latitude)
# Out:
# -42.769201
# -41.383333
# -40.916667
# -43.483333
# City
# southbridge   -43.816667
# southbridge    42.075000
# Name: Latitude, dtype: float64
# -40.3
# -41.768011
# -34.7
# -22.627778
# -33.666667
# -20.1030556
# City
# nata   -20.216667
# nata     8.333333
# Name: Latitude, dtype: float64
# -24.45
# -21.366667
# -18.533333
# -7.95
# -5.116667
# -8.083333
# -6.178056
# -0.6155556
# -0.9333333
# City
# santo tomas    10.757730
# santo tomas    12.066667
# santo tomas   -14.445556
# santo tomas     8.185833
# santo tomas    17.399724
# santo tomas    14.183333
# santo tomas    14.992300
# santo tomas    16.082600
# santo tomas    15.754000
# santo tomas    13.640833
# Name: Latitude, dtype: float64
# 14.096667
# City
# ipil    13.513200
# ipil    10.975800
# ipil     9.790700
# ipil     7.784444
# Name: Latitude, dtype: float64
# City
# boston    52.983333
# boston     7.871111
# boston    42.358333
# Name: Latitude, dtype: float64
# 7.205676
# City
# san andres     6.903333
# san andres    12.584722
# san andres     6.811478
# san andres    16.966667
# san andres     8.600000
# san andres    13.261400
# san andres    14.050000
# san andres    15.722200
# san andres    14.003527
# san andres    13.322700
# Name: Latitude, dtype: float64
# 4.8151
# 37.8333333
# 39.32
# 28.686768
# 38.7327778
# 32.266043
# 30.7541667
# City
# saginaw    43.419444
# saginaw    32.860000
# Name: Latitude, dtype: float64
# 47.420159
# City
# krasnoarmeysk    53.847778
# krasnoarmeysk    56.100000
# krasnoarmeysk    51.023889
# krasnoarmeysk    48.281976
# Name: Latitude, dtype: float64
# 44.55
# 42.9405556
# City
# fundeni    45.533333
# fundeni    44.383333
# Name: Latitude, dtype: float64
# 51.819079
# 52.35236
# 69.966667
# City
# ilinskiy    61.013459
# ilinskiy    47.997778
# ilinskiy    58.572170
# Name: Latitude, dtype: float64
# 61.078451
# 60.964444
# 60.05
# 63.416667
# 65.7

# %%
pd.DataFrame(city_selection)
# Out:
#                      City                                           Latitude
# 0             new norfolk                                           -42.7807
# 1                havelock  City
# havelock    44.433333
# havelock   -41.2833...
# 2                  sanson                                           -40.2167
# 3                 fairlie  City
# fairlie    55.75
# fairlie   -44.10
# Name: L...
# 4              ulverstone                                           -41.1603
# 5                 takapau                                           -40.0333
# 6                la union  City
# la union   -40.283333
# la union     5.9743...
# 7   sao jose do rio preto                                              -20.8
# 8                   alice  City
# alice    27.751944
# alice   -32.787493
# Nam...
# 9            muniz freire                                           -20.4667
# 10                  patea                                           -39.7583
# 11    sao jose do calcado                                           -21.0333
# 12            clevelandia                                              -26.4
# 13               ruatoria                                           -37.8833
# 14                pacanga                                           -7.16667
# 15             pentecoste                                               -3.8
# 16                 camamu                                             -13.95
# 17                manaira                                               -7.7
# 18                 halalo                                             -13.35
# 19     axixa do tocantins                                           -5.55111
# 20          santo estevao                                           -12.4333
# 21             manjeshwar                                               12.7
# 22               san jose  City
# san jose   -17.850000
# san jose     5.0016...
# 23               la guama                                            14.8833
# 24              thanh hoa                                               19.8
# 25            san agustin  City
# san agustin     1.878629
# san agustin    1...
# 26               hacienda                                             15.936
# 27                 bongor                                            10.2806
# 28                 sangod                                            24.9167
# 29       saint pete beach                                             27.725
# 30             ocean city                                            39.2775
# 31          winter garden                                             28.565
# 32                 pundri                                              29.75
# 33              lancaster  City
# lancaster    54.066667
# lancaster    34.69...
# 34                waianae                                            21.4447
# 35                   mako                                            46.2167
# 36                 dobrin                                            47.2833
# 37             brook park                                            41.3983
# 38             baiculesti                                            45.0667
# 39    murovani kurylivtsi                                            48.7235
# 40      horka nad moravou                                            49.6389
# 41                 veroli                                            41.6833
# 42              skalistyy                                            69.2551
# 43           snezhnogorsk  City
# snezhnogorsk    68.093056
# snezhnogorsk   ...
# 44             ust-tsilma                                             65.441
# 45              cheuskiny                                            61.1167
# 46           kuzmolovskiy                                            60.1092
# 47                 nyurba                                            63.2842
# 48                 oppdal                                               62.6

# %%
print(df.loc[df['City'] == 'bulls']['Latitude'])
# Out:
# 26194   -40.166667
# Name: Latitude, dtype: float64

# %%
list(df.loc[(df['Latitude'] > -60) & (df['Latitude'] <= -40),:]['City'])
# Out:
# ['comodoro rivadavia',
#  'puerto madryn',
#  'rawson',
#  'rio gallegos',
#  'san carlos de bariloche',
#  'trelew',
#  'ushuaia',
#  'viedma',
#  'burnie',
#  'devonport',
#  'hobart',
#  'launceston',
#  'new norfolk',
#  'ulverstone',
#  'ancud',
#  'calbuco',
#  'castro',
#  'coihaique',
#  'la union',
#  'osorno',
#  'puerto montt',
#  'puerto varas',
#  'punta arenas',
#  'purranque',
#  'rio bueno',
#  'amberley',
#  'balclutha',
#  'bluff',
#  'brightwater',
#  'bulls',
#  'burnham',
#  'christchurch',
#  'clyde',
#  'darfield',
#  'dobson',
#  'dunedin',
#  'edendale',
#  'fairlie',
#  'foxton',
#  'greymouth',
#  'hanmer springs',
#  'havelock',
#  'himatangi',
#  'hokitika',
#  'invercargill',
#  'kaitangata',
#  'karamea',
#  'leeston',
#  'levin',
#  'lincoln',
#  'lower hutt',
#  'mapua',
#  'masterton',
#  'methven',
#  'milton',
#  'murchison',
#  'nelson',
#  'otaki',
#  'otautau',
#  'outram',
#  'oxford',
#  'palmerston north',
#  'pareora',
#  'pleasant point',
#  'porirua',
#  'rakaia',
#  'ranfurly',
#  'reefton',
#  'riverton',
#  'riwaka',
#  'rolleston',
#  'rongotea',
#  'sanson',
#  'seddon',
#  'sefton',
#  'southbridge',
#  'takaka',
#  'takapau',
#  'te anau',
#  'te horo',
#  'timaru',
#  'tokomaru',
#  'tuatapere',
#  'waikuku',
#  'waipawa',
#  'waitati',
#  'wakefield',
#  'wallacetown',
#  'wanaka',
#  'wellington',
#  'westport',
#  'winton',
#  'woodend',
#  'wyndham']

# %%
pd.DataFrame(df['Latitude'].groupby(df['City']).unique()).head()
# Out:
#                    Latitude
# City
# a               [63.966667]
# a coruna        [43.366609]
# a dos cunhados   [39.15237]
# aabenraa        [55.036217]
# aabybro             [57.15]

# %%
data.count()
# Out:
# Country      46832
# City         46831
# Latitude     46832
# Longitude    46832
# dtype: int64

# %%
lat_lng = [ rd.randint(-60,-40), rd.randint(-80,-60) ]
lat_lng
# Out:
# [-57, -65]

# %%
lat_lng_ranges = [[(-60,-40),(-80,-60),(160,180)],
                   [(-40,-20),(-80,-40),(10,50),(110,180)],
                   [(-20,0),(-80,-30),(10,50),(110,170)],
                   [(0,20),(-80,-30),(-20,60),(70,130)],
                   [(20,40),(-130,-70),(-20,70),(70,150)],
                   [(40,60),(-180,-150),(-140,-50),(-10,170)],
                   [(60,80),(-180,0),(0,180)]]

lat_long_list = []
while len(lat_long_list) < 1000:
    for ln in lat_lng_ranges:
        for i in range(1,len(ln)):
            lat_long_list.append( [rd.randint(ln[0][0],ln[0][1]), rd.randint(ln[i][0],ln[i][1])] )

print(len(lat_long_list))
for i in range (0,10):
    print(lat_long_list[i])
# Out:
# 1007
# [-60, -80]
# [-40, 170]
# [-29, -63]
# [-39, 44]
# [-21, 153]
# [-7, -49]
# [-8, 28]
# [-5, 134]
# [8, -37]
# [13, 35]

# %%
cords = rd.sample(lat_long_list,1)
lat = cords[0][0]
lng = cords[0][1]
print("latitude: {}".format(lat))
print("longitude: {}".format(lng))
# Out:
# latitude: -10
# longitude: -74

# %%
##  http://api.openweathermap.org/data/2.5/find?lat=55.5&lon=37.5&cnt=10
